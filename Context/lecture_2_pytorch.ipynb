# %% [markdown]
# # Setup
#
# 1. Install Conda, e.g. https://www.anaconda.com/docs/getting-started/miniconda/install
#
#     source ~/miniconda3/bin/activate
#
#
# 2. Create and add new environment to your Jupyter notebook
#
#    https://medium.com/@nrk25693/how-to-add-your-conda-environment-to-your-jupyter-notebook-in-just-4-steps-abeab8b8d084
#
#
#     conda create --name llms
#
#     conda activate llms
#
#     conda install -c anaconda ipykernel
#
#     python -m ipykernel install --user --name=llms
#
#
# 3. Install packages
#
#     conda install numpy
#
# https://pytorch.org/get-started/locally/
#
#     pip3 install torch torchvision torchaudio
#
#     conda install transformers

# %% [markdown]
# # PyTorch

# %%
import torch

# %%
x = torch.tensor([1, 2, 3])
x

# %%
torch.arange(1, 9)

# %%
# returns the indices of the maximum value of all elements in the input tensor
torch.argmax(x)

# %%
y = torch.tensor([4, 5, 6])
y

# %%
z = x @ y
z

# %%
# concatenates tensors
torch.cat((x, y))

# %%
torch.stack((x, y))

# %%
# shape as input argument
x = torch.Tensor(2, 3, 4)
print(x)

# %%
dim = (2, 3, 4)
torch.zeros(dim)

# %%
torch.ones(dim)

# %%
# torch.manual_seed(329)
random = torch.rand(3, 5)
print(random)

# %%
random.shape

# %%
# adds an additional dimension to the tensor
new_random = random.unsqueeze(0)
new_random

# %%
# “singleton” dimension
new_random.shape

# %%
new_random = random.unsqueeze(1)
new_random

# %%
new_random.shape

# %%
class NeuralNetwork(torch.nn.Module):
    def __init__(self, num_inputs, num_outputs):
        super().__init__()

        self.layers = torch.nn.Sequential(
                
            # 1st hidden layer
            torch.nn.Linear(num_inputs, 30),
            torch.nn.ReLU(),

            # 2nd hidden layer
            torch.nn.Linear(30, 20),
            torch.nn.ReLU(),

            # output layer
            torch.nn.Linear(20, num_outputs),
        )

    def forward(self, x):
        logits = self.layers(x)
        return logits
